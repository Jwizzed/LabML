# %% [markdown]
# # Import Tools

# %%
import os
import json
import cv2
import numpy as np
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt
import torch
HOME = os.getcwd()
print(HOME)
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# C:\Users\USER\Downloads\DeepFashion2

# %%
# !pip install -q ultralytics supervision --upgrade supervision
from ultralytics import YOLO
import supervision as sv

# %%
DATA_PATH = f"{HOME}/yolov9/deepfashion2-m-11k-1"
IMAGE_PATH = f"{HOME}/yolov9/deepfashion2-m-11k-1/train/images"
WEIGHT_PATH = f"{HOME}/yolov9/weights/yolov9c.pt"
# SINGLE_IMAGE = IMAGE_PATH + "/000001_png.rf.3efc63de2fe2bab8882abc87437bf048.jpg"
SINGLE_IMAGE = "yolov9/mytest/5.jpeg"

# %% [markdown]
# # Get the model

# %%
# model = YOLO(WEIGHT_PATH)
# model.info()

# %%
model = YOLO(f"{HOME}/runs/detect/train18/weights/best.pt")
model.info()
# Out:
# YOLOv9c summary: 618 layers, 25539255 parameters, 0 gradients, 103.7 GFLOPs
# (618, 25539255, 0, 103.73452800000001)

# %%
pp_model = YOLO("yolov9/weights/yolov9c.pt")
pp_model.info()
# Out:
# YOLOv9c summary: 618 layers, 25590912 parameters, 0 gradients, 104.0 GFLOPs
# (618, 25590912, 0, 104.02268160000003)

# %%
# model.val(data=DATA_PATH+"/data.yaml",imgsz=480,batch=16,conf=0.25,iou=0.6,device='0')

# %% [markdown]
# # Get the data

# %%
# rf = Roboflow(api_key="grBnAXmaVyCZOXlCtfQ7")
# project = rf.workspace("bmstu-lvj0c").project("deepfashion2-m-11k")
# version = project.version(1)
# dataset = version.download("yolov9")

# %%
# Image(filename=f"{HOME}/yolov9/runs/detect/exp/000001_png.rf.3efc63de2fe2bab8882abc87437bf048.jpg", width=600)

# %% [markdown]
# # Model Training

# %%
# results = model.train(data=f'{DATA_PATH}/data.yaml', epochs=1000, imgsz=480)

# %% [markdown]
# # Inference

# %%
test = [f"yolov9/mytest/{file}" for file in os.listdir("yolov9/mytest")]
test
# Out:
# ['yolov9/mytest/1.jpg',
#  'yolov9/mytest/10.jpg',
#  'yolov9/mytest/10484263.webp',
#  'yolov9/mytest/11.jpg',
#  'yolov9/mytest/12.jpg',
#  'yolov9/mytest/13.jpg',
#  'yolov9/mytest/14.jpg',
#  'yolov9/mytest/15.jpg',
#  'yolov9/mytest/16.jpg',
#  'yolov9/mytest/17.jpg',
#  'yolov9/mytest/18.jpg',
#  'yolov9/mytest/19.jpg',
#  'yolov9/mytest/2.jpg',
#  'yolov9/mytest/3.jpg',
#  'yolov9/mytest/4.jpg',
#  'yolov9/mytest/5.jpeg',
#  'yolov9/mytest/6.jpeg',
#  'yolov9/mytest/6.jpg',
#  'yolov9/mytest/7.jpg',
#  'yolov9/mytest/8.webp',
#  'yolov9/mytest/9.jpg',
#  'yolov9/mytest/9.webp']

# %%
results = model(test, imgsz=480)
results[0]
# Out:
# 0: 480x480 2 long sleeve outwears, 1 trousers, 22.5ms
# 1: 480x480 2 long sleeve outwears, 2 long sleeve tops, 6 short sleeve tops, 6 shortss, 7 trouserss, 22.5ms
# 2: 480x480 1 skirt, 1 vest dress, 22.5ms
# 3: 480x480 1 long sleeve outwear, 1 short sleeve top, 1 skirt, 1 trousers, 22.5ms
# 4: 480x480 3 long sleeve outwears, 1 long sleeve top, 6 trouserss, 22.5ms
# 5: 480x480 2 short sleeve dresss, 1 short sleeve top, 1 shorts, 22.5ms
# 6: 480x480 1 long sleeve outwear, 2 short sleeve tops, 1 shorts, 3 trouserss, 1 vest dress, 22.5ms
# 7: 480x480 (no detections), 22.5ms
# 8: 480x480 (no detections), 22.5ms
# 9: 480x480 (no detections), 22.5ms
# 10: 480x480 (no detections), 22.5ms
# 11: 480x480 1 short sleeve top, 22.5ms
# 12: 480x480 1 short sleeve top, 1 trousers, 22.5ms
# 13: 480x480 1 trousers, 1 vest, 22.5ms
# 14: 480x480 (no detections), 22.5ms
# 15: 480x480 4 long sleeve outwears, 2 long sleeve tops, 2 short sleeve tops, 7 trouserss, 22.5ms
# 16: 480x480 1 long sleeve outwear, 4 trouserss, 22.5ms
# 17: 480x480 (no detections), 22.5ms
# 18: 480x480 1 long sleeve dress, 2 long sleeve tops, 22.5ms
# 19: 480x480 (no detections), 22.5ms
# 20: 480x480 (no detections), 22.5ms
# 21: 480x480 3 short sleeve tops, 2 skirts, 1 vest, 22.5ms
# Speed: 1.9ms preprocess, 22.5ms inference, 19.5ms postprocess per image at shape (1, 3, 480, 480)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
# obb: None
# orig_img: array([[[251, 251, 251],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [195, 195, 195],
#         [196, 196, 196]],
#
#        [[249, 249, 249],
#         [255, 255, 255],
#         [252, 252, 252],
#         ...,
#         [253, 253, 253],
#         [193, 193, 193],
#         [199, 199, 199]],
#
#        [[241, 241, 241],
#         [248, 248, 248],
#         [250, 250, 250],
#         ...,
#         [251, 251, 251],
#         [195, 195, 195],
#         [192, 192, 192]],
#
#        ...,
#
#        [[209, 209, 209],
#         [201, 201, 201],
#         [199, 199, 199],
#         ...,
#         [194, 194, 194],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        [[195, 195, 195],
#         [193, 193, 193],
#         [202, 202, 202],
#         ...,
#         [202, 202, 202],
#         [248, 248, 248],
#         [247, 247, 247]],
#
#        [[233, 233, 233],
#         [231, 231, 231],
#         [236, 236, 236],
#         ...,
#         [203, 203, 203],
#         [227, 227, 227],
#         [209, 209, 209]]], dtype=uint8)
# orig_shape: (275, 183)
# path: 'yolov9/mytest/1.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict5'
# speed: {'preprocess': 1.865343614058061, 'inference': 22.52042293548584, 'postprocess': 19.51730251312256}

# %%
pp_results = pp_model(test, imgsz=480)
pp_results[0]
# Out:
# 0: 480x480 1 person, 27.1ms
# 1: 480x480 20 persons, 1 backpack, 4 handbags, 27.1ms
# 2: 480x480 1 person, 1 sports ball, 27.1ms
# 3: 480x480 8 persons, 2 bicycles, 12 cars, 11 traffic lights, 2 handbags, 1 tie, 27.1ms
# 4: 480x480 12 persons, 1 truck, 1 traffic light, 1 backpack, 4 handbags, 1 suitcase, 1 clock, 27.1ms
# 5: 480x480 13 persons, 6 cars, 2 buss, 2 traffic lights, 1 backpack, 6 handbags, 1 suitcase, 27.1ms
# 6: 480x480 13 persons, 4 cars, 1 handbag, 1 tie, 27.1ms
# 7: 480x480 12 persons, 4 backpacks, 2 handbags, 27.1ms
# 8: 480x480 1 person, 27.1ms
# 9: 480x480 9 persons, 1 car, 1 bus, 27.1ms
# 10: 480x480 31 persons, 1 bicycle, 1 handbag, 27.1ms
# 11: 480x480 17 persons, 27.1ms
# 12: 480x480 1 person, 27.1ms
# 13: 480x480 1 person, 27.1ms
# 14: 480x480 1 person, 2 books, 27.1ms
# 15: 480x480 11 persons, 1 truck, 1 traffic light, 3 handbags, 27.1ms
# 16: 480x480 12 persons, 2 bicycles, 1 car, 1 bus, 1 truck, 3 backpacks, 2 handbags, 27.1ms
# 17: 480x480 12 persons, 27.1ms
# 18: 480x480 8 persons, 1 tie, 27.1ms
# 19: 480x480 23 persons, 1 bicycle, 2 motorcycles, 27.1ms
# 20: 480x480 15 persons, 2 bicycles, 2 motorcycles, 27.1ms
# 21: 480x480 10 persons, 1 tie, 27.1ms
# Speed: 1.3ms preprocess, 27.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[251, 251, 251],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [195, 195, 195],
#         [196, 196, 196]],
#
#        [[249, 249, 249],
#         [255, 255, 255],
#         [252, 252, 252],
#         ...,
#         [253, 253, 253],
#         [193, 193, 193],
#         [199, 199, 199]],
#
#        [[241, 241, 241],
#         [248, 248, 248],
#         [250, 250, 250],
#         ...,
#         [251, 251, 251],
#         [195, 195, 195],
#         [192, 192, 192]],
#
#        ...,
#
#        [[209, 209, 209],
#         [201, 201, 201],
#         [199, 199, 199],
#         ...,
#         [194, 194, 194],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        [[195, 195, 195],
#         [193, 193, 193],
#         [202, 202, 202],
#         ...,
#         [202, 202, 202],
#         [248, 248, 248],
#         [247, 247, 247]],
#
#        [[233, 233, 233],
#         [231, 231, 231],
#         [236, 236, 236],
#         ...,
#         [203, 203, 203],
#         [227, 227, 227],
#         [209, 209, 209]]], dtype=uint8)
# orig_shape: (275, 183)
# path: 'yolov9/mytest/1.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict5'
# speed: {'preprocess': 1.319375905123624, 'inference': 27.070056308399547, 'postprocess': 1.000501892783425}

# %% [markdown]
# # SAM

# %%
# !pip install -q git+https://github.com/facebookresearch/segment-anything.git
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor
# CHECKPOINT_PATH = f"{HOME}/yolov9/weights/sam_vit_h_4b8939.pth"
CHECKPOINT_PATH = f"{HOME}/yolov9/weights/sam_vit_b_01ec64.pth"

# MODEL_TYPE = "vit_h"
MODEL_TYPE = "vit_b"

# %%
sv.Color
# Out:
# supervision.draw.color.Color

# %%
sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)
mask_predictor = SamPredictor(sam)

box_annotator = sv.BoundingBoxAnnotator(color=sv.Color.YELLOW, color_lookup = sv.ColorLookup.INDEX)
mask_annotator = sv.MaskAnnotator(color_lookup = sv.ColorLookup.INDEX)
label_annotator = sv.LabelAnnotator(text_position=sv.Position.CENTER, color_lookup = sv.ColorLookup.INDEX)
corner_annotator = sv.BoxCornerAnnotator(color=sv.Color.GREEN)

# %%
for i, pr in enumerate(pp_results):    
    annotated_image = cv2.imread(pr.path)
    mask_predictor.set_image(annotated_image)
    
    pp_detections = sv.Detections.from_ultralytics(pr)
    pp_detections = pp_detections[pp_detections.class_id == 0]
    annotated_image = corner_annotator.annotate(annotated_image, pp_detections)
    
    for box in pr.boxes:
        input_box = np.array(box.xyxy.tolist()[0])
        masks, _, _ = mask_predictor.predict(
            point_coords=None,
            point_labels=None,
            box=input_box[None, :],
            multimask_output=False,
        )

        pp_detections = sv.Detections(
            xyxy=sv.mask_to_xyxy(masks=masks),
            mask=masks,
            class_id=np.array(box.cls.tolist()),
            confidence=np.array(box.conf.tolist())
        ).with_nms(threshold=0.1)
        pp_detections = pp_detections[pp_detections.class_id == 0]
        annotated_image = mask_annotator.annotate(scene=annotated_image, detections=pp_detections)
    
    
    # Fashion
    result = results[i]
    detections = sv.Detections.from_ultralytics(result)
    labels = [f"{result.names[class_id]} {confidence:.2f}" for xy, mask, confidence, class_id, tracker_id, data in detections]

    annotated_image = box_annotator.annotate(scene=annotated_image, detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections, labels=labels)
    

    sv.plot_images_grid(
        images=[annotated_image],
        grid_size=(2, 1),
        titles=['segmented image']
    )
    
    # Save annotted image
    with sv.ImageSink(target_dir_path='runs/detect/manual/', overwrite=False) as sink:
        sink.save_image(image=annotated_image, image_name=f"test{i}.png")

# %%
pp_results[21].show()

# %%
pp_results[21].save_crop("person")

# %%
model("person/person", imgsz=480, save=True)
# Out:
# image 1/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg.jpg: 480x448 1 long sleeve top, 150.1ms
# image 2/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg10.jpg: 480x224 1 long sleeve outwear, 1 skirt, 54.0ms
# image 3/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg11.jpg: 480x224 1 short sleeve top, 1 trousers, 20.0ms
# image 4/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg12.jpg: 480x128 1 long sleeve top, 1 trousers, 20.0ms
# image 5/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg13.jpg: 480x160 1 long sleeve outwear, 1 trousers, 92.1ms
# image 6/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg14.jpg: 480x224 1 long sleeve top, 1 trousers, 80.1ms
# image 7/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg15.jpg: 480x160 2 long sleeve outwears, 1 skirt, 1 trousers, 71.1ms
# image 8/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg16.jpg: 480x256 1 long sleeve dress, 1 skirt, 63.1ms
# image 9/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg17.jpg: 480x192 1 long sleeve outwear, 1 trousers, 113.1ms
# image 10/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg18.jpg: 480x192 2 long sleeve outwears, 1 trousers, 18.0ms
# image 11/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg19.jpg: 480x128 2 short sleeve tops, 1 trousers, 18.0ms
# image 12/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg2.jpg: 480x480 (no detections), 19.0ms
# image 13/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg20.jpg: 480x192 1 long sleeve outwear, 121.1ms
# image 14/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg21.jpg: 480x224 1 short sleeve top, 1 trousers, 95.1ms
# image 15/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg22.jpg: 480x320 1 shorts, 1 trousers, 1 vest dress, 139.1ms
# image 16/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg23.jpg: 480x288 1 long sleeve top, 1 shorts, 82.1ms
# image 17/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg24.jpg: 480x448 1 long sleeve top, 2 short sleeve tops, 120.1ms
# image 18/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg25.jpg: 480x256 1 short sleeve top, 1 shorts, 20.0ms
# image 19/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg26.jpg: 480x384 2 long sleeve tops, 21.0ms
# image 20/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg27.jpg: 480x224 2 long sleeve tops, 1 short sleeve dress, 66.1ms
# image 21/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg28.jpg: 480x416 1 short sleeve dress, 1 short sleeve top, 124.1ms
# image 22/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg29.jpg: 480x224 1 short sleeve dress, 114.1ms
# image 23/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg3.jpg: 480x384 1 long sleeve top, 148.1ms
# image 24/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg30.jpg: 480x384 1 short sleeve top, 86.1ms
# image 25/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg31.jpg: 480x224 1 short sleeve top, 1 trousers, 20.0ms
# image 26/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg32.jpg: 480x320 1 shorts, 1 trousers, 1 vest dress, 19.0ms
# image 27/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg33.jpg: 480x288 1 long sleeve top, 1 shorts, 87.1ms
# image 28/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg34.jpg: 480x448 1 long sleeve top, 2 short sleeve tops, 90.1ms
# image 29/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg35.jpg: 480x256 1 short sleeve top, 1 shorts, 116.1ms
# image 30/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg36.jpg: 480x384 2 long sleeve tops, 127.1ms
# image 31/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg37.jpg: 480x224 2 long sleeve tops, 1 short sleeve dress, 111.1ms
# image 32/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg38.jpg: 480x416 1 short sleeve dress, 1 short sleeve top, 27.0ms
# image 33/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg39.jpg: 480x224 1 short sleeve dress, 19.0ms
# image 34/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg4.jpg: 480x384 1 long sleeve top, 135.1ms
# image 35/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg40.jpg: 480x384 1 short sleeve top, 98.1ms
# image 36/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg5.jpg: 480x448 1 long sleeve top, 160.1ms
# image 37/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg6.jpg: 352x480 (no detections), 73.1ms
# image 38/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg7.jpg: 480x480 1 skirt, 116.1ms
# image 39/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg8.jpg: 352x480 (no detections), 56.1ms
# image 40/40 C:\Users\USER\Downloads\DeepFashion2\person\person\im.jpg9.jpg: 480x160 (no detections), 23.0ms
# Speed: 3.4ms preprocess, 78.3ms inference, 35.9ms postprocess per image at shape (1, 3, 480, 160)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[209, 211, 211],
#          [208, 210, 210],
#          [209, 211, 211],
#          ...,
#          [206, 206, 206],
#          [207, 207, 207],
#          [207, 207, 207]],
#
#         [[210, 212, 212],
#          [210, 212, 212],
#          [210, 212, 212],
#          ...,
#          [208, 208, 208],
#          [209, 209, 209],
#          [209, 209, 209]],
#
#         [[211, 213, 213],
#          [211, 213, 213],
#          [211, 213, 213],
#          ...,
#          [209, 209, 209],
#          [209, 209, 209],
#          [209, 209, 209]],
#
#         ...,
#
#         [[186, 188, 188],
#          [192, 195, 193],
#          [195, 198, 196],
#          ...,
#          [167, 162, 159],
#          [162, 157, 159],
#          [ 83,  77,  82]],
#
#         [[193, 195, 195],
#          [194, 197, 195],
#          [195, 198, 196],
#          ...,
#          [189, 184, 183],
#          [102,  97,  99],
#          [ 70,  64,  69]],
#
#         [[196, 198, 198],
#          [199, 202, 200],
#          [197, 200, 198],
#          ...,
#          [143, 138, 137],
#          [ 76,  71,  73],
#          [ 88,  82,  87]]], dtype=uint8)
#  orig_shape: (119, 108)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 2.0036697387695312, 'inference': 150.1317024230957, 'postprocess': 80.07287979125977},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[101,  96,  75],
#          [114, 107,  87],
#          [123, 115,  92],
#          ...,
#          [ 96, 106,  83],
#          [119, 129, 106],
#          [108, 119,  93]],
#
#         [[106, 102,  78],
#          [113, 107,  84],
#          [118, 110,  87],
#          ...,
#          [158, 165, 144],
#          [157, 164, 143],
#          [125, 135, 112]],
#
#         [[109, 105,  77],
#          [115, 110,  85],
#          [118, 111,  86],
#          ...,
#          [189, 195, 178],
#          [219, 225, 208],
#          [180, 189, 169]],
#
#         ...,
#
#         [[ 46,  48,  48],
#          [ 45,  47,  47],
#          [ 45,  46,  44],
#          ...,
#          [158, 144, 116],
#          [158, 144, 116],
#          [155, 141, 113]],
#
#         [[ 47,  49,  49],
#          [ 46,  49,  47],
#          [ 46,  47,  45],
#          ...,
#          [155, 141, 118],
#          [161, 147, 124],
#          [163, 149, 126]],
#
#         [[ 51,  52,  50],
#          [ 49,  50,  48],
#          [ 49,  48,  44],
#          ...,
#          [149, 133, 110],
#          [155, 140, 114],
#          [170, 155, 129]]], dtype=uint8)
#  orig_shape: (465, 208)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg10.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 6.000757217407227, 'inference': 54.04829978942871, 'postprocess': 2.001047134399414},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 95,  94,  60],
#          [101,  99,  68],
#          [ 85,  83,  52],
#          ...,
#          [120, 115,  90],
#          [ 98,  93,  68],
#          [111, 106,  81]],
#
#         [[101,  99,  68],
#          [117, 115,  84],
#          [113, 111,  80],
#          ...,
#          [151, 147, 123],
#          [130, 126, 102],
#          [132, 128, 104]],
#
#         [[ 93,  90,  62],
#          [111, 109,  79],
#          [104, 104,  74],
#          ...,
#          [155, 151, 127],
#          [148, 146, 122],
#          [159, 157, 133]],
#
#         ...,
#
#         [[230, 222, 229],
#          [228, 220, 227],
#          [227, 219, 226],
#          ...,
#          [218, 209, 206],
#          [219, 207, 205],
#          [218, 207, 203]],
#
#         [[228, 221, 226],
#          [226, 219, 224],
#          [224, 217, 222],
#          ...,
#          [217, 208, 205],
#          [221, 210, 206],
#          [222, 210, 206]],
#
#         [[228, 220, 227],
#          [227, 219, 226],
#          [226, 218, 225],
#          ...,
#          [214, 202, 196],
#          [215, 203, 197],
#          [217, 205, 199]]], dtype=uint8)
#  orig_shape: (401, 164)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg11.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.0025501251220703, 'inference': 20.019054412841797, 'postprocess': 1.0008811950683594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 69,  65,  47],
#          [ 70,  66,  48],
#          [ 61,  55,  36],
#          ...,
#          [192, 199, 194],
#          [201, 209, 209],
#          [191, 202, 206]],
#
#         [[ 67,  64,  50],
#          [ 78,  73,  58],
#          [ 77,  72,  57],
#          ...,
#          [206, 212, 207],
#          [209, 214, 217],
#          [216, 222, 229]],
#
#         [[138, 135, 127],
#          [138, 136, 126],
#          [138, 134, 123],
#          ...,
#          [210, 215, 213],
#          [215, 218, 223],
#          [218, 219, 229]],
#
#         ...,
#
#         [[203, 194, 184],
#          [193, 184, 175],
#          [191, 182, 173],
#          ...,
#          [ 74,  63,  31],
#          [ 73,  62,  30],
#          [ 73,  62,  30]],
#
#         [[207, 198, 185],
#          [196, 186, 176],
#          [191, 180, 172],
#          ...,
#          [ 79,  68,  36],
#          [ 78,  67,  35],
#          [ 75,  64,  32]],
#
#         [[205, 196, 183],
#          [205, 196, 183],
#          [203, 193, 183],
#          ...,
#          [ 84,  71,  39],
#          [ 81,  70,  38],
#          [ 77,  66,  34]]], dtype=uint8)
#  orig_shape: (390, 94)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg12.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 0.0, 'inference': 20.017385482788086, 'postprocess': 1.0018348693847656},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 53,  41,   0],
#          [ 63,  49,   7],
#          [ 99,  82,  39],
#          ...,
#          [ 59,  58,  44],
#          [ 72,  67,  52],
#          [ 91,  83,  70]],
#
#         [[ 63,  49,   7],
#          [ 79,  63,  21],
#          [ 63,  46,   3],
#          ...,
#          [ 61,  60,  46],
#          [ 71,  66,  51],
#          [107, 100,  85]],
#
#         [[ 64,  48,   6],
#          [ 94,  77,  34],
#          [ 77,  58,  15],
#          ...,
#          [ 66,  63,  49],
#          [ 67,  62,  47],
#          [121, 114,  99]],
#
#         ...,
#
#         [[219, 211, 212],
#          [222, 214, 215],
#          [225, 217, 217],
#          ...,
#          [219, 212, 215],
#          [222, 215, 218],
#          [221, 214, 217]],
#
#         [[212, 204, 204],
#          [215, 207, 207],
#          [217, 210, 207],
#          ...,
#          [221, 214, 217],
#          [220, 213, 216],
#          [220, 215, 217]],
#
#         [[222, 217, 214],
#          [217, 212, 209],
#          [215, 208, 205],
#          ...,
#          [228, 221, 224],
#          [231, 226, 228],
#          [238, 233, 235]]], dtype=uint8)
#  orig_shape: (432, 134)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg13.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.0001659393310547, 'inference': 92.08369255065918, 'postprocess': 50.04477500915527},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 43,  31,  13],
#          [ 40,  34,  11],
#          [ 47,  43,  18],
#          ...,
#          [ 45,  40,   9],
#          [ 45,  42,  11],
#          [ 35,  29,   0]],
#
#         [[ 33,  22,   0],
#          [ 37,  30,   5],
#          [ 36,  33,   5],
#          ...,
#          [ 43,  40,   9],
#          [ 46,  43,  12],
#          [ 36,  30,   1]],
#
#         [[ 39,  30,   3],
#          [ 36,  30,   1],
#          [ 29,  27,   0],
#          ...,
#          [ 43,  40,   9],
#          [ 46,  44,  10],
#          [ 34,  31,   0]],
#
#         ...,
#
#         [[137, 122,  96],
#          [120, 105,  79],
#          [108,  93,  67],
#          ...,
#          [112, 101,  69],
#          [115, 104,  72],
#          [117, 106,  74]],
#
#         [[175, 161, 139],
#          [169, 155, 133],
#          [149, 135, 112],
#          ...,
#          [145, 132, 100],
#          [138, 125,  93],
#          [136, 123,  91]],
#
#         [[204, 190, 171],
#          [217, 203, 184],
#          [203, 189, 170],
#          ...,
#          [155, 141, 112],
#          [136, 122,  93],
#          [129, 115,  86]]], dtype=uint8)
#  orig_shape: (400, 165)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg14.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 6.005764007568359, 'inference': 80.08098602294922, 'postprocess': 60.05454063415527},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[206, 199, 196],
#          [242, 235, 240],
#          [242, 236, 247],
#          ...,
#          [193, 191, 190],
#          [183, 179, 178],
#          [183, 180, 175]],
#
#         [[199, 194, 191],
#          [237, 233, 238],
#          [239, 238, 247],
#          ...,
#          [197, 194, 196],
#          [187, 182, 183],
#          [180, 177, 173]],
#
#         [[191, 186, 185],
#          [231, 227, 233],
#          [242, 241, 251],
#          ...,
#          [200, 199, 203],
#          [188, 185, 187],
#          [174, 169, 170]],
#
#         ...,
#
#         [[230, 222, 223],
#          [231, 223, 224],
#          [229, 221, 222],
#          ...,
#          [233, 225, 226],
#          [233, 225, 226],
#          [238, 230, 231]],
#
#         [[225, 218, 223],
#          [224, 217, 222],
#          [224, 217, 220],
#          ...,
#          [234, 227, 234],
#          [234, 227, 234],
#          [234, 227, 234]],
#
#         [[222, 215, 220],
#          [221, 214, 219],
#          [221, 214, 217],
#          ...,
#          [236, 228, 238],
#          [236, 228, 238],
#          [236, 228, 238]]], dtype=uint8)
#  orig_shape: (378, 125)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg15.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 4.003286361694336, 'inference': 71.07281684875488, 'postprocess': 24.01280403137207},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 32,  38,  37],
#          [ 40,  45,  46],
#          [ 53,  58,  61],
#          ...,
#          [ 32,  38,   7],
#          [ 30,  36,   1],
#          [ 35,  39,   3]],
#
#         [[ 31,  40,  37],
#          [ 40,  46,  45],
#          [ 51,  56,  57],
#          ...,
#          [ 73,  80,  47],
#          [ 37,  43,   8],
#          [ 32,  36,   0]],
#
#         [[ 34,  43,  40],
#          [ 42,  50,  49],
#          [ 52,  57,  58],
#          ...,
#          [ 69,  76,  43],
#          [ 42,  47,  15],
#          [ 25,  28,   0]],
#
#         ...,
#
#         [[ 21,  20,   0],
#          [ 21,  20,   0],
#          [ 21,  20,   0],
#          ...,
#          [137, 120,  93],
#          [159, 144, 118],
#          [154, 138, 115]],
#
#         [[ 21,  20,   0],
#          [ 21,  20,   0],
#          [ 21,  20,   0],
#          ...,
#          [147, 131, 102],
#          [152, 135, 109],
#          [151, 136, 110]],
#
#         [[ 21,  20,   0],
#          [ 21,  20,   0],
#          [ 21,  20,   0],
#          ...,
#          [150, 134, 105],
#          [152, 135, 109],
#          [148, 133, 107]]], dtype=uint8)
#  orig_shape: (698, 351)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg16.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 5.004167556762695, 'inference': 63.059091567993164, 'postprocess': 127.11262702941895},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[183, 195, 207],
#          [108, 116, 123],
#          [ 21,  26,  25],
#          ...,
#          [176, 176, 212],
#          [126, 127, 155],
#          [ 70,  70,  88]],
#
#         [[141, 150, 163],
#          [ 35,  41,  48],
#          [  6,  10,  11],
#          ...,
#          [126, 127, 165],
#          [ 87,  88, 114],
#          [ 64,  67,  81]],
#
#         [[ 98, 104, 115],
#          [  7,  11,  16],
#          [ 22,  26,  27],
#          ...,
#          [ 81,  83, 123],
#          [ 47,  51,  76],
#          [ 46,  50,  61]],
#
#         ...,
#
#         [[191, 178, 162],
#          [189, 176, 160],
#          [186, 173, 157],
#          ...,
#          [161, 147, 128],
#          [164, 150, 131],
#          [165, 150, 131]],
#
#         [[183, 173, 156],
#          [182, 172, 155],
#          [178, 168, 151],
#          ...,
#          [170, 156, 137],
#          [170, 156, 137],
#          [170, 156, 137]],
#
#         [[172, 164, 147],
#          [170, 162, 145],
#          [169, 161, 144],
#          ...,
#          [166, 152, 133],
#          [164, 150, 131],
#          [165, 151, 132]]], dtype=uint8)
#  orig_shape: (304, 118)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg17.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 7.014989852905273, 'inference': 113.10291290283203, 'postprocess': 31.028270721435547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 83,  81,  63],
#          [112, 109,  94],
#          [119, 116, 102],
#          ...,
#          [ 52,  43,  10],
#          [ 45,  36,   2],
#          [ 55,  52,  21]],
#
#         [[ 91,  87,  69],
#          [104, 100,  82],
#          [116, 111,  96],
#          ...,
#          [ 72,  63,  36],
#          [ 77,  69,  40],
#          [ 87,  86,  58]],
#
#         [[ 82,  75,  56],
#          [ 75,  68,  51],
#          [ 73,  66,  51],
#          ...,
#          [ 89,  80,  60],
#          [ 93,  86,  66],
#          [ 93,  93,  69]],
#
#         ...,
#
#         [[ 79,  69,  81],
#          [124, 114, 120],
#          [126, 115, 111],
#          ...,
#          [159, 144, 118],
#          [159, 144, 118],
#          [153, 138, 112]],
#
#         [[ 64,  54,  54],
#          [ 87,  76,  72],
#          [ 94,  85,  72],
#          ...,
#          [149, 136, 110],
#          [145, 131, 108],
#          [146, 133, 107]],
#
#         [[116, 108, 101],
#          [134, 125, 115],
#          [153, 144, 130],
#          ...,
#          [142, 128, 105],
#          [134, 120,  97],
#          [135, 123,  99]]], dtype=uint8)
#  orig_shape: (359, 121)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg18.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.0013580322265625, 'inference': 18.01609992980957, 'postprocess': 1.0004043579101562},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 68,  67,  33],
#          [ 73,  69,  41],
#          [ 76,  71,  50],
#          ...,
#          [ 50,  49,  99],
#          [ 62,  59, 138],
#          [ 60,  51, 148]],
#
#         [[ 67,  65,  35],
#          [ 86,  81,  56],
#          [109, 105,  86],
#          ...,
#          [ 65,  62, 131],
#          [ 67,  62, 147],
#          [ 72,  63, 160]],
#
#         [[ 62,  61,  35],
#          [ 99,  95,  70],
#          [178, 173, 158],
#          ...,
#          [ 80,  77, 149],
#          [115, 115, 185],
#          [146, 144, 214]],
#
#         ...,
#
#         [[226, 215, 217],
#          [225, 213, 213],
#          [227, 215, 215],
#          ...,
#          [ 66,  47,   2],
#          [ 53,  37,   0],
#          [ 40,  29,   0]],
#
#         [[190, 178, 172],
#          [181, 170, 162],
#          [180, 167, 159],
#          ...,
#          [ 66,  47,   2],
#          [ 53,  37,   0],
#          [ 41,  30,   0]],
#
#         [[152, 139, 123],
#          [139, 126, 110],
#          [134, 120, 102],
#          ...,
#          [ 65,  46,   3],
#          [ 54,  38,   1],
#          [ 42,  31,   1]]], dtype=uint8)
#  orig_shape: (331, 85)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg19.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 0.9999275207519531, 'inference': 18.014907836914062, 'postprocess': 1.0004043579101562},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[188, 193, 192],
#          [188, 193, 192],
#          [188, 193, 192],
#          ...,
#          [ 24,  29,  28],
#          [ 34,  38,  39],
#          [ 22,  25,  29]],
#
#         [[191, 196, 195],
#          [190, 195, 194],
#          [190, 195, 194],
#          ...,
#          [ 35,  37,  37],
#          [ 10,  14,  15],
#          [ 18,  21,  25]],
#
#         [[191, 196, 195],
#          [190, 195, 194],
#          [189, 194, 193],
#          ...,
#          [ 36,  38,  38],
#          [ 26,  28,  29],
#          [ 19,  20,  24]],
#
#         ...,
#
#         [[188, 191, 189],
#          [187, 192, 190],
#          [182, 187, 185],
#          ...,
#          [184, 187, 185],
#          [185, 188, 186],
#          [185, 188, 186]],
#
#         [[187, 190, 188],
#          [188, 191, 189],
#          [182, 185, 183],
#          ...,
#          [186, 189, 187],
#          [187, 190, 188],
#          [186, 189, 187]],
#
#         [[186, 189, 187],
#          [187, 190, 188],
#          [180, 183, 181],
#          ...,
#          [183, 186, 184],
#          [185, 188, 186],
#          [185, 188, 186]]], dtype=uint8)
#  orig_shape: (76, 79)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg2.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.0018348693847656, 'inference': 19.016504287719727, 'postprocess': 2.027273178100586},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[235, 228, 241],
#          [235, 230, 245],
#          [231, 231, 245],
#          ...,
#          [166, 156, 168],
#          [199, 188, 190],
#          [215, 205, 198]],
#
#         [[236, 229, 244],
#          [235, 232, 248],
#          [234, 233, 249],
#          ...,
#          [177, 166, 169],
#          [200, 189, 185],
#          [210, 201, 188]],
#
#         [[235, 228, 243],
#          [233, 227, 244],
#          [230, 227, 243],
#          ...,
#          [187, 175, 171],
#          [197, 187, 177],
#          [202, 192, 174]],
#
#         ...,
#
#         [[126, 116,  99],
#          [121, 111,  93],
#          [116, 106,  88],
#          ...,
#          [ 29,  25,   0],
#          [ 29,  23,   0],
#          [ 28,  22,   0]],
#
#         [[121, 108,  92],
#          [116, 104,  86],
#          [115, 103,  85],
#          ...,
#          [ 31,  27,   2],
#          [ 31,  26,   1],
#          [ 31,  26,   1]],
#
#         [[138, 127, 107],
#          [130, 119,  99],
#          [124, 113,  93],
#          ...,
#          [ 32,  28,   3],
#          [ 32,  27,   2],
#          [ 32,  27,   2]]], dtype=uint8)
#  orig_shape: (193, 70)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg20.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 0.9989738464355469, 'inference': 121.11043930053711, 'postprocess': 17.014503479003906},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 69,  93, 111],
#          [ 71,  95, 113],
#          [ 81, 105, 123],
#          ...,
#          [106, 147, 162],
#          [112, 153, 168],
#          [117, 158, 173]],
#
#         [[ 72,  96, 114],
#          [ 73,  97, 115],
#          [ 82, 106, 124],
#          ...,
#          [ 75, 116, 131],
#          [ 81, 122, 137],
#          [ 86, 127, 142]],
#
#         [[ 72,  96, 114],
#          [ 73,  97, 115],
#          [ 80, 104, 122],
#          ...,
#          [100, 141, 156],
#          [101, 142, 157],
#          [101, 141, 159]],
#
#         ...,
#
#         [[ 70,  79, 106],
#          [ 74,  84, 108],
#          [ 76,  84, 107],
#          ...,
#          [ 66,  83,  96],
#          [ 68,  85,  98],
#          [ 70,  89, 102]],
#
#         [[ 69,  78, 105],
#          [ 71,  81, 105],
#          [ 73,  81, 104],
#          ...,
#          [ 63,  82,  95],
#          [ 64,  83,  96],
#          [ 68,  87, 100]],
#
#         [[ 72,  81, 108],
#          [ 69,  79, 103],
#          [ 71,  79, 102],
#          ...,
#          [ 63,  82,  95],
#          [ 63,  82,  95],
#          [ 65,  87,  99]]], dtype=uint8)
#  orig_shape: (493, 209)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg21.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 6.006479263305664, 'inference': 95.08562088012695, 'postprocess': 42.0382022857666},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[119, 146, 160],
#          [119, 146, 160],
#          [119, 146, 160],
#          ...,
#          [112, 118, 123],
#          [115, 121, 126],
#          [114, 120, 125]],
#
#         [[116, 145, 160],
#          [116, 145, 160],
#          [116, 145, 160],
#          ...,
#          [115, 124, 128],
#          [109, 118, 122],
#          [112, 121, 125]],
#
#         [[117, 146, 161],
#          [117, 146, 161],
#          [116, 145, 160],
#          ...,
#          [108, 116, 123],
#          [111, 119, 126],
#          [110, 118, 125]],
#
#         ...,
#
#         [[134, 148, 154],
#          [131, 145, 151],
#          [131, 145, 151],
#          ...,
#          [ 75,  77,  77],
#          [ 68,  70,  70],
#          [ 63,  65,  65]],
#
#         [[132, 148, 154],
#          [128, 144, 150],
#          [123, 139, 145],
#          ...,
#          [ 89,  91,  91],
#          [ 82,  84,  84],
#          [ 76,  78,  78]],
#
#         [[132, 149, 152],
#          [127, 144, 147],
#          [121, 138, 141],
#          ...,
#          [ 79,  81,  81],
#          [ 80,  82,  82],
#          [ 82,  84,  84]]], dtype=uint8)
#  orig_shape: (461, 288)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg22.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 9.009361267089844, 'inference': 139.11724090576172, 'postprocess': 80.07240295410156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[145, 164, 209],
#          [142, 160, 207],
#          [139, 155, 202],
#          ...,
#          [105, 124, 185],
#          [105, 124, 185],
#          [106, 125, 186]],
#
#         [[149, 167, 214],
#          [146, 163, 212],
#          [142, 159, 208],
#          ...,
#          [100, 119, 180],
#          [100, 119, 180],
#          [100, 119, 180]],
#
#         [[151, 168, 219],
#          [148, 164, 217],
#          [145, 161, 214],
#          ...,
#          [ 88, 110, 168],
#          [ 86, 108, 166],
#          [ 85, 107, 165]],
#
#         ...,
#
#         [[126, 150, 186],
#          [128, 152, 188],
#          [129, 153, 189],
#          ...,
#          [ 80,  84,  89],
#          [ 92,  98, 103],
#          [ 86,  95,  99]],
#
#         [[126, 150, 186],
#          [128, 152, 188],
#          [129, 153, 189],
#          ...,
#          [ 79,  83,  88],
#          [ 90,  96, 101],
#          [ 85,  91,  96]],
#
#         [[126, 150, 186],
#          [128, 152, 188],
#          [129, 153, 189],
#          ...,
#          [ 81,  84,  89],
#          [ 91,  95, 100],
#          [ 86,  90,  95]]], dtype=uint8)
#  orig_shape: (437, 235)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg23.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 7.007598876953125, 'inference': 82.08227157592773, 'postprocess': 82.07416534423828},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 86, 114, 131],
#          [ 91, 120, 135],
#          [ 94, 123, 138],
#          ...,
#          [ 48,  60,  84],
#          [ 50,  63,  85],
#          [ 45,  58,  80]],
#
#         [[ 90, 118, 135],
#          [ 95, 124, 139],
#          [ 97, 126, 141],
#          ...,
#          [ 49,  61,  85],
#          [ 51,  64,  86],
#          [ 48,  61,  83]],
#
#         [[ 96, 124, 141],
#          [ 96, 124, 141],
#          [100, 129, 144],
#          ...,
#          [ 43,  55,  79],
#          [ 47,  60,  82],
#          [ 44,  57,  79]],
#
#         ...,
#
#         [[103,  83, 156],
#          [103,  83, 156],
#          [103,  83, 156],
#          ...,
#          [145, 154, 157],
#          [151, 160, 163],
#          [130, 141, 145]],
#
#         [[103,  82, 157],
#          [103,  83, 156],
#          [103,  83, 156],
#          ...,
#          [144, 156, 158],
#          [150, 161, 165],
#          [134, 144, 151]],
#
#         [[103,  83, 158],
#          [103,  83, 158],
#          [103,  84, 157],
#          ...,
#          [135, 146, 150],
#          [142, 153, 157],
#          [130, 142, 148]]], dtype=uint8)
#  orig_shape: (223, 195)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg24.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 7.007837295532227, 'inference': 120.10836601257324, 'postprocess': 3.001689910888672},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 38,  36,  36],
#          [ 39,  37,  37],
#          [ 38,  36,  36],
#          ...,
#          [220, 193, 172],
#          [220, 193, 172],
#          [223, 194, 173]],
#
#         [[ 38,  36,  36],
#          [ 38,  36,  36],
#          [ 40,  38,  38],
#          ...,
#          [220, 193, 173],
#          [215, 188, 167],
#          [214, 185, 164]],
#
#         [[ 38,  36,  36],
#          [ 37,  35,  35],
#          [ 39,  37,  37],
#          ...,
#          [217, 189, 172],
#          [210, 183, 163],
#          [208, 181, 161]],
#
#         ...,
#
#         [[110, 128, 135],
#          [100, 118, 125],
#          [ 96, 114, 121],
#          ...,
#          [109, 128, 136],
#          [ 97, 116, 129],
#          [ 99, 118, 133]],
#
#         [[102, 120, 127],
#          [ 92, 110, 117],
#          [ 89, 107, 114],
#          ...,
#          [105, 127, 138],
#          [ 94, 115, 130],
#          [ 96, 116, 133]],
#
#         [[ 87, 105, 112],
#          [ 80,  98, 105],
#          [ 79,  97, 104],
#          ...,
#          [104, 128, 140],
#          [ 93, 116, 132],
#          [ 97, 117, 135]]], dtype=uint8)
#  orig_shape: (471, 237)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg25.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.0020732879638672, 'inference': 20.017147064208984, 'postprocess': 2.001047134399414},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 54,  91, 125],
#          [ 53,  90, 124],
#          [ 53,  90, 124],
#          ...,
#          [104, 141, 163],
#          [106, 143, 165],
#          [112, 149, 171]],
#
#         [[ 46,  84, 116],
#          [ 45,  82, 116],
#          [ 46,  83, 117],
#          ...,
#          [107, 140, 160],
#          [107, 140, 160],
#          [109, 142, 162]],
#
#         [[ 52,  90, 122],
#          [ 49,  87, 119],
#          [ 46,  83, 117],
#          ...,
#          [108, 139, 160],
#          [107, 138, 159],
#          [106, 137, 158]],
#
#         ...,
#
#         [[211, 203, 196],
#          [223, 215, 208],
#          [220, 212, 205],
#          ...,
#          [175, 171, 170],
#          [187, 184, 180],
#          [199, 196, 192]],
#
#         [[203, 195, 188],
#          [204, 198, 191],
#          [207, 201, 194],
#          ...,
#          [174, 171, 167],
#          [187, 184, 180],
#          [200, 197, 192]],
#
#         [[205, 199, 192],
#          [195, 189, 182],
#          [210, 204, 197],
#          ...,
#          [175, 170, 167],
#          [187, 184, 179],
#          [201, 198, 193]]], dtype=uint8)
#  orig_shape: (280, 220)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg26.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 2.001523971557617, 'inference': 21.018266677856445, 'postprocess': 2.0017623901367188},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 35,  37,  38],
#          [ 38,  33,  35],
#          [ 46,  37,  40],
#          ...,
#          [ 98, 106, 136],
#          [ 95, 104, 137],
#          [ 86,  97, 129]],
#
#         [[ 34,  34,  40],
#          [ 39,  35,  41],
#          [ 41,  33,  40],
#          ...,
#          [ 98, 106, 136],
#          [ 88,  97, 130],
#          [ 78,  89, 121]],
#
#         [[ 32,  32,  44],
#          [ 37,  33,  44],
#          [ 40,  32,  42],
#          ...,
#          [ 91,  99, 129],
#          [ 68,  77, 110],
#          [ 60,  69, 102]],
#
#         ...,
#
#         [[181, 189, 189],
#          [180, 188, 188],
#          [180, 188, 188],
#          ...,
#          [104,  78,  48],
#          [104,  77,  50],
#          [105,  78,  51]],
#
#         [[182, 190, 190],
#          [182, 190, 190],
#          [182, 190, 190],
#          ...,
#          [112,  87,  55],
#          [108,  82,  52],
#          [107,  81,  51]],
#
#         [[182, 190, 190],
#          [182, 190, 190],
#          [182, 190, 190],
#          ...,
#          [121,  93,  62],
#          [115,  87,  56],
#          [112,  84,  53]]], dtype=uint8)
#  orig_shape: (415, 188)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg27.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.0001659393310547, 'inference': 66.05768203735352, 'postprocess': 75.06966590881348},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[123, 110, 132],
#          [227, 213, 237],
#          [173, 158, 185],
#          ...,
#          [ 46,  41,  42],
#          [ 45,  43,  43],
#          [ 55,  50,  51]],
#
#         [[168, 155, 177],
#          [214, 200, 224],
#          [164, 149, 176],
#          ...,
#          [ 48,  43,  44],
#          [ 49,  44,  45],
#          [ 58,  52,  53]],
#
#         [[114, 101, 125],
#          [181, 168, 192],
#          [170, 157, 183],
#          ...,
#          [ 52,  47,  48],
#          [ 52,  46,  47],
#          [ 61,  53,  54]],
#
#         ...,
#
#         [[ 89, 105, 118],
#          [ 81,  97, 110],
#          [ 88, 101, 115],
#          ...,
#          [ 84,  66,  65],
#          [ 78,  65,  63],
#          [ 77,  64,  62]],
#
#         [[ 84, 101, 114],
#          [ 81,  97, 109],
#          [ 86, 100, 112],
#          ...,
#          [ 86,  68,  67],
#          [ 79,  66,  64],
#          [ 79,  66,  64]],
#
#         [[ 82, 102, 113],
#          [ 81,  97, 110],
#          [ 89, 100, 114],
#          ...,
#          [ 84,  69,  67],
#          [ 83,  68,  66],
#          [ 83,  68,  66]]], dtype=uint8)
#  orig_shape: (313, 266)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg28.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 8.007287979125977, 'inference': 124.12118911743164, 'postprocess': 79.0719985961914},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 52,  59,  54],
#          [ 51,  58,  53],
#          [ 52,  59,  54],
#          ...,
#          [ 70,  83,  97],
#          [ 66,  75,  84],
#          [ 83,  90,  93]],
#
#         [[ 42,  48,  43],
#          [ 43,  49,  44],
#          [ 48,  54,  49],
#          ...,
#          [ 67,  80,  96],
#          [ 61,  71,  81],
#          [ 77,  83,  88]],
#
#         [[ 32,  37,  35],
#          [ 32,  37,  35],
#          [ 34,  39,  37],
#          ...,
#          [ 67,  81, 100],
#          [ 59,  68,  82],
#          [ 71,  78,  87]],
#
#         ...,
#
#         [[187, 165, 167],
#          [191, 167, 169],
#          [196, 169, 172],
#          ...,
#          [123, 124, 120],
#          [124, 125, 121],
#          [129, 128, 124]],
#
#         [[185, 163, 165],
#          [189, 165, 167],
#          [195, 168, 171],
#          ...,
#          [122, 123, 119],
#          [124, 123, 119],
#          [125, 124, 120]],
#
#         [[180, 158, 160],
#          [186, 162, 164],
#          [192, 165, 168],
#          ...,
#          [128, 129, 125],
#          [128, 127, 123],
#          [124, 123, 119]]], dtype=uint8)
#  orig_shape: (405, 171)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg29.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 7.006168365478516, 'inference': 114.11237716674805, 'postprocess': 34.03067588806152},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[205, 200, 199],
#          [205, 197, 197],
#          [204, 196, 196],
#          ...,
#          [196, 201, 199],
#          [193, 198, 196],
#          [196, 201, 199]],
#
#         [[214, 206, 206],
#          [208, 200, 200],
#          [215, 205, 205],
#          ...,
#          [195, 200, 198],
#          [196, 201, 199],
#          [195, 200, 198]],
#
#         [[217, 209, 209],
#          [225, 217, 217],
#          [215, 205, 205],
#          ...,
#          [191, 196, 194],
#          [196, 201, 199],
#          [193, 198, 196]],
#
#         ...,
#
#         [[160, 165, 164],
#          [161, 167, 166],
#          [160, 168, 167],
#          ...,
#          [169, 174, 173],
#          [199, 204, 203],
#          [192, 197, 196]],
#
#         [[159, 164, 163],
#          [160, 166, 165],
#          [158, 166, 165],
#          ...,
#          [163, 168, 167],
#          [195, 200, 199],
#          [188, 193, 192]],
#
#         [[161, 166, 165],
#          [163, 169, 168],
#          [160, 168, 167],
#          ...,
#          [167, 172, 171],
#          [202, 207, 206],
#          [194, 199, 198]]], dtype=uint8)
#  orig_shape: (100, 77)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg3.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.9915103912353516, 'inference': 148.13494682312012, 'postprocess': 80.07192611694336},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 36,  62,  86],
#          [ 42,  67,  87],
#          [ 50,  73,  89],
#          ...,
#          [131,  84,  46],
#          [134,  87,  49],
#          [161, 114,  76]],
#
#         [[ 42,  68,  92],
#          [ 43,  67,  89],
#          [ 49,  72,  88],
#          ...,
#          [194, 136, 100],
#          [184, 129,  92],
#          [216, 162, 127]],
#
#         [[ 51,  76, 102],
#          [ 47,  71,  93],
#          [ 49,  71,  89],
#          ...,
#          [250, 197, 160],
#          [231, 182, 144],
#          [255, 212, 175]],
#
#         ...,
#
#         [[ 69,  78,  82],
#          [ 47,  55,  62],
#          [ 44,  50,  61],
#          ...,
#          [166, 172, 177],
#          [159, 163, 168],
#          [163, 167, 172]],
#
#         [[ 69,  77,  84],
#          [ 50,  57,  66],
#          [ 42,  48,  59],
#          ...,
#          [164, 168, 173],
#          [145, 149, 154],
#          [145, 148, 156]],
#
#         [[ 69,  77,  84],
#          [ 49,  56,  65],
#          [ 40,  46,  57],
#          ...,
#          [154, 160, 165],
#          [153, 159, 166],
#          [145, 151, 158]]], dtype=uint8)
#  orig_shape: (178, 139)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg30.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 7.007122039794922, 'inference': 86.08484268188477, 'postprocess': 22.02129364013672},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 69,  93, 111],
#          [ 71,  95, 113],
#          [ 81, 105, 123],
#          ...,
#          [106, 147, 162],
#          [112, 153, 168],
#          [117, 158, 173]],
#
#         [[ 72,  96, 114],
#          [ 73,  97, 115],
#          [ 82, 106, 124],
#          ...,
#          [ 75, 116, 131],
#          [ 81, 122, 137],
#          [ 86, 127, 142]],
#
#         [[ 72,  96, 114],
#          [ 73,  97, 115],
#          [ 80, 104, 122],
#          ...,
#          [100, 141, 156],
#          [101, 142, 157],
#          [101, 141, 159]],
#
#         ...,
#
#         [[ 70,  79, 106],
#          [ 74,  84, 108],
#          [ 76,  84, 107],
#          ...,
#          [ 66,  83,  96],
#          [ 68,  85,  98],
#          [ 70,  89, 102]],
#
#         [[ 69,  78, 105],
# ...
#  orig_shape: (415, 188)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg37.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.003265380859375, 'inference': 111.10687255859375, 'postprocess': 18.01609992980957},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[123, 110, 132],
#          [227, 213, 237],
#          [173, 158, 185],
#          ...,
#          [ 46,  41,  42],
#          [ 45,  43,  43],
#          [ 55,  50,  51]],
#
#         [[168, 155, 177],
#          [214, 200, 224],
#          [164, 149, 176],
#          ...,
#          [ 48,  43,  44],
#          [ 49,  44,  45],
#          [ 58,  52,  53]],
#
#         [[114, 101, 125],
#          [181, 168, 192],
#          [170, 157, 183],
#          ...,
#          [ 52,  47,  48],
#          [ 52,  46,  47],
#          [ 61,  53,  54]],
#
#         ...,
#
#         [[ 89, 105, 118],
#          [ 81,  97, 110],
#          [ 88, 101, 115],
#          ...,
#          [ 84,  66,  65],
#          [ 78,  65,  63],
#          [ 77,  64,  62]],
#
#         [[ 84, 101, 114],
#          [ 81,  97, 109],
#          [ 86, 100, 112],
#          ...,
#          [ 86,  68,  67],
#          [ 79,  66,  64],
#          [ 79,  66,  64]],
#
#         [[ 82, 102, 113],
#          [ 81,  97, 110],
#          [ 89, 100, 114],
#          ...,
#          [ 84,  69,  67],
#          [ 83,  68,  66],
#          [ 83,  68,  66]]], dtype=uint8)
#  orig_shape: (313, 266)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg38.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.003265380859375, 'inference': 27.022123336791992, 'postprocess': 1.001119613647461},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 52,  59,  54],
#          [ 51,  58,  53],
#          [ 52,  59,  54],
#          ...,
#          [ 70,  83,  97],
#          [ 66,  75,  84],
#          [ 83,  90,  93]],
#
#         [[ 42,  48,  43],
#          [ 43,  49,  44],
#          [ 48,  54,  49],
#          ...,
#          [ 67,  80,  96],
#          [ 61,  71,  81],
#          [ 77,  83,  88]],
#
#         [[ 32,  37,  35],
#          [ 32,  37,  35],
#          [ 34,  39,  37],
#          ...,
#          [ 67,  81, 100],
#          [ 59,  68,  82],
#          [ 71,  78,  87]],
#
#         ...,
#
#         [[187, 165, 167],
#          [191, 167, 169],
#          [196, 169, 172],
#          ...,
#          [123, 124, 120],
#          [124, 125, 121],
#          [129, 128, 124]],
#
#         [[185, 163, 165],
#          [189, 165, 167],
#          [195, 168, 171],
#          ...,
#          [122, 123, 119],
#          [124, 123, 119],
#          [125, 124, 120]],
#
#         [[180, 158, 160],
#          [186, 162, 164],
#          [192, 165, 168],
#          ...,
#          [128, 129, 125],
#          [128, 127, 123],
#          [124, 123, 119]]], dtype=uint8)
#  orig_shape: (405, 171)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg39.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 0.9922981262207031, 'inference': 19.01984214782715, 'postprocess': 0.9984970092773438},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[174, 179, 177],
#          [175, 180, 178],
#          [171, 176, 174],
#          ...,
#          [198, 201, 199],
#          [200, 203, 201],
#          [198, 203, 201]],
#
#         [[173, 178, 176],
#          [182, 187, 185],
#          [165, 170, 168],
#          ...,
#          [193, 198, 196],
#          [201, 206, 204],
#          [200, 205, 203]],
#
#         [[174, 179, 177],
#          [179, 184, 182],
#          [165, 170, 168],
#          ...,
#          [190, 197, 194],
#          [193, 200, 197],
#          [196, 201, 199]],
#
#         ...,
#
#         [[  1,   8,  25],
#          [ 19,  25,  38],
#          [ 42,  48,  55],
#          ...,
#          [178, 180, 180],
#          [182, 184, 184],
#          [183, 185, 185]],
#
#         [[ 25,  32,  49],
#          [ 11,  16,  31],
#          [  5,  10,  19],
#          ...,
#          [193, 195, 195],
#          [193, 195, 195],
#          [193, 195, 195]],
#
#         [[155, 158, 186],
#          [160, 166, 189],
#          [104, 111, 130],
#          ...,
#          [190, 192, 192],
#          [188, 190, 190],
#          [188, 190, 190]]], dtype=uint8)
#  orig_shape: (97, 73)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg4.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.0018348693847656, 'inference': 135.12134552001953, 'postprocess': 3.002643585205078},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 36,  62,  86],
#          [ 42,  67,  87],
#          [ 50,  73,  89],
#          ...,
#          [131,  84,  46],
#          [134,  87,  49],
#          [161, 114,  76]],
#
#         [[ 42,  68,  92],
#          [ 43,  67,  89],
#          [ 49,  72,  88],
#          ...,
#          [194, 136, 100],
#          [184, 129,  92],
#          [216, 162, 127]],
#
#         [[ 51,  76, 102],
#          [ 47,  71,  93],
#          [ 49,  71,  89],
#          ...,
#          [250, 197, 160],
#          [231, 182, 144],
#          [255, 212, 175]],
#
#         ...,
#
#         [[ 69,  78,  82],
#          [ 47,  55,  62],
#          [ 44,  50,  61],
#          ...,
#          [166, 172, 177],
#          [159, 163, 168],
#          [163, 167, 172]],
#
#         [[ 69,  77,  84],
#          [ 50,  57,  66],
#          [ 42,  48,  59],
#          ...,
#          [164, 168, 173],
#          [145, 149, 154],
#          [145, 148, 156]],
#
#         [[ 69,  77,  84],
#          [ 49,  56,  65],
#          [ 40,  46,  57],
#          ...,
#          [154, 160, 165],
#          [153, 159, 166],
#          [145, 151, 158]]], dtype=uint8)
#  orig_shape: (178, 139)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg40.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 2.003192901611328, 'inference': 98.08802604675293, 'postprocess': 60.06312370300293},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[230, 230, 230],
#          [236, 236, 236],
#          [243, 243, 243],
#          ...,
#          [209, 211, 211],
#          [209, 211, 211],
#          [209, 211, 211]],
#
#         [[230, 230, 230],
#          [237, 237, 237],
#          [242, 242, 242],
#          ...,
#          [209, 211, 211],
#          [209, 211, 211],
#          [209, 211, 211]],
#
#         [[228, 230, 230],
#          [238, 238, 238],
#          [242, 242, 242],
#          ...,
#          [209, 211, 211],
#          [209, 211, 211],
#          [209, 211, 211]],
#
#         ...,
#
#         [[ 28,  26,  26],
#          [ 12,  10,  10],
#          [ 36,  34,  34],
#          ...,
#          [167, 172, 170],
#          [171, 174, 172],
#          [161, 164, 162]],
#
#         [[ 36,  34,  34],
#          [ 29,  27,  27],
#          [ 24,  22,  22],
#          ...,
#          [202, 205, 203],
#          [205, 206, 204],
#          [198, 199, 197]],
#
#         [[ 36,  34,  34],
#          [ 32,  30,  30],
#          [ 31,  29,  29],
#          ...,
#          [191, 192, 190],
#          [191, 192, 190],
#          [189, 187, 186]]], dtype=uint8)
#  orig_shape: (102, 91)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg5.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 7.004737854003906, 'inference': 160.13741493225098, 'postprocess': 78.0794620513916},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[ 58,  79,  77],
#          [ 67,  85,  84],
#          [ 70,  88,  89],
#          ...,
#          [184, 189, 187],
#          [155, 160, 158],
#          [191, 196, 194]],
#
#         [[ 72,  93,  91],
#          [ 76,  94,  93],
#          [ 86, 104, 105],
#          ...,
#          [186, 191, 189],
#          [158, 163, 161],
#          [198, 203, 201]],
#
#         [[ 65,  83,  84],
#          [ 26,  44,  45],
#          [  1,  16,  18],
#          ...,
#          [186, 191, 189],
#          [160, 165, 163],
#          [199, 204, 202]],
#
#         ...,
#
#         [[194, 199, 202],
#          [195, 200, 201],
#          [174, 179, 180],
#          ...,
#          [200, 202, 202],
#          [171, 173, 173],
#          [169, 171, 171]],
#
#         [[195, 200, 203],
#          [193, 198, 199],
#          [170, 175, 176],
#          ...,
#          [200, 202, 202],
#          [171, 174, 172],
#          [169, 170, 168]],
#
#         [[194, 199, 202],
#          [190, 195, 196],
#          [169, 173, 174],
#          ...,
#          [201, 203, 203],
#          [170, 173, 171],
#          [167, 170, 168]]], dtype=uint8)
#  orig_shape: (73, 105)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg6.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 3.0019283294677734, 'inference': 73.0743408203125, 'postprocess': 33.020734786987305},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[209, 213, 214],
#          [212, 214, 214],
#          [211, 213, 213],
#          ...,
#          [102, 119, 122],
#          [103, 120, 123],
#          [106, 121, 124]],
#
#         [[211, 213, 213],
#          [210, 212, 212],
#          [208, 210, 210],
#          ...,
#          [ 88, 104, 110],
#          [109, 123, 129],
#          [121, 135, 141]],
#
#         [[211, 213, 213],
#          [210, 212, 212],
#          [211, 213, 213],
#          ...,
#          [ 91, 107, 114],
#          [115, 128, 136],
#          [125, 138, 146]],
#
#         ...,
#
#         [[183, 185, 185],
#          [182, 184, 184],
#          [183, 185, 185],
#          ...,
#          [184, 186, 186],
#          [185, 187, 187],
#          [186, 188, 188]],
#
#         [[182, 184, 184],
#          [178, 180, 180],
#          [178, 180, 180],
#          ...,
#          [186, 188, 188],
#          [185, 187, 187],
#          [186, 188, 188]],
#
#         [[185, 187, 187],
#          [185, 187, 187],
#          [185, 187, 187],
#          ...,
#          [186, 188, 188],
#          [186, 188, 188],
#          [186, 188, 188]]], dtype=uint8)
#  orig_shape: (97, 92)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg7.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 7.999658584594727, 'inference': 116.11223220825195, 'postprocess': 80.07407188415527},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[110, 109, 111],
#          [161, 163, 164],
#          [188, 190, 191],
#          ...,
#          [187, 189, 189],
#          [189, 191, 191],
#          [188, 190, 190]],
#
#         [[161, 160, 162],
#          [175, 177, 178],
#          [161, 163, 164],
#          ...,
#          [186, 188, 188],
#          [187, 189, 189],
#          [188, 190, 190]],
#
#         [[169, 171, 172],
#          [192, 194, 195],
#          [146, 148, 149],
#          ...,
#          [185, 187, 187],
#          [187, 189, 189],
#          [187, 189, 189]],
#
#         ...,
#
#         [[187, 192, 195],
#          [189, 194, 197],
#          [189, 194, 197],
#          ...,
#          [195, 196, 194],
#          [194, 199, 198],
#          [195, 200, 199]],
#
#         [[183, 188, 191],
#          [184, 189, 192],
#          [184, 189, 192],
#          ...,
#          [197, 198, 196],
#          [191, 197, 196],
#          [195, 200, 199]],
#
#         [[180, 185, 188],
#          [180, 185, 188],
#          [180, 185, 188],
#          ...,
#          [202, 205, 203],
#          [199, 205, 204],
#          [202, 207, 206]]], dtype=uint8)
#  orig_shape: (75, 105)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg8.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 8.008241653442383, 'inference': 56.05268478393555, 'postprocess': 1.0020732879638672},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'long sleeve dress', 1: 'long sleeve outwear', 2: 'long sleeve top', 3: 'short sleeve dress', 4: 'short sleeve outwear', 5: 'short sleeve top', 6: 'shorts', 7: 'skirt', 8: 'sling', 9: 'sling dress', 10: 'trousers', 11: 'vest', 12: 'vest dress'}
#  obb: None
#  orig_img: array([[[231, 207, 171],
#          [231, 207, 171],
#          [231, 207, 171],
#          ...,
#          [251, 231, 200],
#          [250, 230, 199],
#          [248, 228, 197]],
#
#         [[234, 210, 174],
#          [234, 210, 174],
#          [234, 210, 174],
#          ...,
#          [255, 235, 204],
#          [255, 235, 204],
#          [255, 235, 204]],
#
#         [[234, 210, 174],
#          [234, 210, 174],
#          [234, 210, 174],
#          ...,
#          [254, 234, 203],
#          [255, 235, 204],
#          [255, 236, 205]],
#
#         ...,
#
#         [[255, 239, 212],
#          [255, 239, 212],
#          [254, 239, 213],
#          ...,
#          [233, 211, 176],
#          [229, 207, 172],
#          [225, 203, 168]],
#
#         [[255, 239, 212],
#          [255, 239, 212],
#          [254, 239, 213],
#          ...,
#          [245, 225, 190],
#          [243, 223, 188],
#          [242, 222, 187]],
#
#         [[255, 239, 212],
#          [255, 239, 212],
#          [254, 239, 213],
#          ...,
#          [246, 226, 191],
#          [252, 232, 197],
#          [255, 236, 201]]], dtype=uint8)
#  orig_shape: (712, 211)
#  path: 'C:\\Users\\USER\\Downloads\\DeepFashion2\\person\\person\\im.jpg9.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict5'
#  speed: {'preprocess': 1.0044574737548828, 'inference': 23.01788330078125, 'postprocess': 0.9996891021728516}]
